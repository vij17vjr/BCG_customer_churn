# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Importing data**

# %%
df = pd.read_csv('client_data.csv')

# %% [markdown]
# ### Index
# **1. Data Cleaning and Converting to the right format** <br>
# **2. Feature Engineering**

# %% [markdown]
# ### 1. Data Cleaning and Converting to the right format

# %%
df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %% [markdown]
# **Converting date columns to Datetime format**

# %%
df["date_activ"] = pd.to_datetime(df["date_activ"], format='%Y-%m-%d')
df["date_end"] = pd.to_datetime(df["date_end"], format='%Y-%m-%d')
df["date_modif_prod"] = pd.to_datetime(df["date_modif_prod"], format='%Y-%m-%d')
df["date_renewal"] = pd.to_datetime(df["date_renewal"], format='%Y-%m-%d')

# %% [markdown]
# **Converting has_gas data type to category to apply label encoding**

# %%
df['has_gas'] = df['has_gas'].astype('category')

# %%
df['has_gas'] = df['has_gas'].cat.codes

# %%
df['has_gas'].value_counts(normalize=True)
# Out:
# 0    0.818499
# 1    0.181501
# Name: has_gas, dtype: float64

# %% [markdown]
# - More that 80% of the customers are not subscribed to gas

# %%
df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        1       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        0       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        0       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %% [markdown]
# **Checking for duplicates and missing values**

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicates nor missing value. **Data is clean**

# %% [markdown]
# ### 2. Feature Engineering

# %%
price_df = pd.read_csv('price_data.csv')
price_df["price_date"] = pd.to_datetime(price_df["price_date"],→format='%Y-%m-%d')
price_df.head()
# Out:
#   File "<ipython-input-35-e1188978cc93>", line 2
#     price_df["price_date"] = pd.to_datetime(price_df["price_date"],→format='%Y-%m-%d')
#                                                                          ^
# SyntaxError: invalid character in identifier
